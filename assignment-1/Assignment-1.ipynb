# %% [markdown]
# ## Question 5 - Programming problem

# %%
import numpy as np
import math
import matplotlib.pyplot as plt


# Params for full-screen graphs
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %% [markdown]
# ### Part a

# %%
def quadratic_data_gererator(x):
    return -0.25*np.square(x)+5

x = np.array([-0.15,-0.05, -0.047, -0.05,0.055,0.052, 0.053])
y = quadratic_data_gererator(data_points)

# %%
# def plt_printer(x, y, fit, title, plt_number):
#     #fig = plt.figure(1)
#     plt.plot(x, y,'bo')
#     plt.subplot(plt_number)
#     plt.title(title)
#     plt.xlabel('x')
#     plt.ylabel('y')
#     return 
    
# plt_printer(x, y, quadratic_data_gererator(x), 'titlz', 131 )


def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(131)
plt.plot(t1, f(t1), 'bo', t2, f(t2), '-k')
plt.title('Histogram of IQ')
plt.xlabel('Smarts')
plt.ylabel('Probability')



plt.subplot(132)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.title('Histogram of IQ')
plt.xlabel('Smarts')
plt.ylabel('Probability')

plt.figure(1)
plt.subplot(133)
plt.plot(x, y, 'bo', x, quadratic_data_gererator(x), '-k' )
plt.title('Underfitting')
plt.xlabel('x')
plt.ylabel('y')
plt.tick_params(axis='both', which='both', bottom='off', top='off', labelbottom='off', left='off', labelleft='off')

plt.show()
