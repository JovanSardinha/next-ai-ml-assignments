# %% [markdown]
# ## Question 5 - Programming problem

# %%
import numpy as np
import numpy.polynomial.polynomial as poly
import math
import matplotlib.pyplot as plt


# Params for full-screen graphs
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %% [markdown]
# ### Part a

# %%
def quadratic_data_gererator(x):
    return -0.25*np.square(x)+5

x = np.array([-0.15,-0.05, -0.047, -0.05,0.065,0.062, 0.063])
y = quadratic_data_gererator(x)

# %%
def fit(x, y, deg):
    coef = np.polyfit(x, y, deg)
    ffit = np.poly1d(coef)
    x_new = np.linspace(x[0], x[-1])
    y_new = ffit(x_new)
    return x_new, y_new

# %%
plt.figure(1)

plt.subplot(131)
x_new, y_new = fit(x, y, 1)
plt.plot(x, y, 'bo', x_new, y_new, '--k')
plt.title('Underfitting')
plt.xlabel('x')
plt.ylabel('y')
plt.tick_params(axis='both', which='both', bottom='off', top='off', labelbottom='off', left='off', labelleft='off')

plt.subplot(132)
x_new, y_new = fit(x, y, 2)
plt.plot(x, y, 'bo', x_new, y_new, '--k')
plt.title('Appropriate Capacity')
plt.xlabel('x')
plt.ylabel('y')
plt.tick_params(axis='both', which='both', bottom='off', top='off', labelbottom='off', left='off', labelleft='off')

plt.subplot(133)
x_new, y_new = fit(x, y, 9)
plt.plot(x, y, 'bo', x_new, y_new, '--k')
plt.title('Overfitting')
plt.xlabel('x')
plt.ylabel('y')
plt.tick_params(axis='both', which='both', bottom='off', top='off', labelbottom='off', left='off', labelleft='off')



plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:2: RankWarning: Polyfit may be poorly conditioned
#   from ipykernel import kernelapp as app

# %%
import numpy as np
import matplotlib.pyplot as plt


# calculate polynomial
z = np.polyfit(x, y, 9)
print(z)
f = np.poly1d(z)

# calculate new x's and y's
x_new = np.linspace(x[0], x[-1])
y_new = f(x_new)

plt.plot(x,y,'o', x_new, y_new)
plt.xlim([x[0]-1, x[-1] + 1 ])
plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:6: RankWarning: Polyfit may be poorly conditioned
# [ -6.28310113e+05   4.04329327e+05   1.82496281e+04   9.76744542e+03
#    1.28065325e+03  -3.00424944e+02  -3.92467733e+00   1.08379964e+00
#    6.95828122e-04   4.99833219e+00]
